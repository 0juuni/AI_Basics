# %% [markdown]
# # 7. Pandas, Matplotlib Visualization

# %% [markdown]
# # 복습
# - Pandas Series
# - Pandas Dataframe

# %%
# Dataframe 만들기 - (1) List 이용하기

import pandas as pd

# row 중심 data frame 생성
data_list = None
columns = None
df1 = pd.DataFrame(data_list, columns=columns)
print(df1)

# %%
# Dataframe 만들기 - (2) Dictionary 이용하기

import pandas as pd

# column 중심  DataFrame 생성
data_dict = None

df2 = pd.DataFrame(data_dict)
print(df2)

# %%
# Dataframe에서 columns-polulation이 500이상인 정보만 가져오기
import pandas as pd

df=pd.DataFrame([['한국',500],['미국', 450],['싱가폴', 705], ['호주', 878],
                ['베트남', 660], ['대만', 808]],
                columns=['country', 'population'])
print(df['population']>=500)

new_df = None
print(new_df)
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# 5     True
# Name: population, dtype: bool
#   country  population
# 0      한국         500
# 2     싱가폴         705
# 3      호주         878
# 4     베트남         660
# 5      대만         808

# %% [markdown]
# ![Image](data:image/png;base64,...)

# %% [markdown]
# ## Visualization
# matplotlib, Seaborn이 대표적
# ![Image](data:image/png;base64,...)
# ![Image](data:image/png;base64,...)
# ![Image](data:image/png;base64,...)
# ![Image](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np

row=4; col=5
df=pd.DataFrame(np.random.randn(row, col))
print(df)
df.plot()
# Out:
#           0         1         2         3         4
# 0  0.408099 -1.371041  0.036042  1.310888 -0.602656
# 1  0.944158 -1.808803  1.477599 -0.489939 -0.156103
# 2  1.149715 -1.941224  0.110657  0.820132 -0.208055
# 3 -1.129950  0.134926  0.094786 -1.016633  1.468322
# <Axes: >

# %%
import pandas as pd
import numpy as np

row=4; col=5
df=pd.DataFrame(np.random.randn(row, col))
print(df)
df.plot()
# Out:
#           0         1         2         3         4
# 0 -0.595020  1.143929  0.010990 -0.327912 -0.619627
# 1 -0.867950  0.270482 -0.204108  2.438079  1.007600
# 2  1.291390 -0.063899  0.356446 -0.025203  0.156802
# 3 -0.176879 -0.083254 -0.115690  0.139182  0.222708
# <Axes: >

# %%
import pandas as pd
import numpy as np

row=4; col=5
np.random.seed(1234)
df=pd.DataFrame(np.random.randn(row, col))
print(df)
df.plot()
# Out:
#           0         1         2         3         4
# 0  0.471435 -1.190976  1.432707 -0.312652 -0.720589
# 1  0.887163  0.859588 -0.636524  0.015696 -2.242685
# 2  1.150036  0.991946  0.953324 -2.021255 -0.334077
# 3  0.002118  0.405453  0.289092  1.321158 -1.546906
# <Axes: >

# %% [markdown]
# ![Image](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np
np.random.seed(0)
df=pd.DataFrame(np.random.randn(100,3),
        index=pd.date_range('1/1/2023', periods=100),
        columns=['A','B','C'])
df1=df.cumsum(); print(df1)
df1.plot(color=['red', 'pink', 'gray'])
# Out:
#                     A          B          C
# 2023-01-01   1.764052   0.400157   0.978738
# 2023-01-02   4.004946   2.267715   0.001460
# 2023-01-03   4.955034   2.116358  -0.101759
# 2023-01-04   5.365632   2.260402   1.352515
# 2023-01-05   6.126670   2.382077   1.796378
# ...               ...        ...        ...
# 2023-04-06   9.396256   6.282026 -11.198087
# 2023-04-07  10.086074   7.583872 -11.826175
# 2023-04-08   9.605047   9.887789 -12.886190
# 2023-04-09   9.469097  11.024680 -12.788465
# 2023-04-10  10.052051  10.625231 -12.418409
#
# [100 rows x 3 columns]
# <Axes: >

# %% [markdown]
# ![Image](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,4), columns=['zero', 'one', 'two', 'three'])
color_list=['blue', 'green', 'red', 'orange']
print(df)
df.plot(kind='barh', color=color_list)
# Out:
#        zero       one       two     three
# 0 -1.613898 -0.212740 -0.895467  0.386902
# 1 -0.510805 -1.180632 -0.028182  0.428332
# 2  0.066517  0.302472 -0.634322 -0.362741
# 3 -0.672460 -0.359553 -0.813146 -1.726283
# <Axes: >

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,4), columns=['zero', 'one', 'two', 'three'])
color_list=['blue', 'green', 'red', 'orange']
print(df)
df.plot(kind='hist', color=color_list, width=0.3)
# Out:
#        zero       one       two     three
# 0  0.010500  1.785870  0.126912  0.401989
# 1  1.883151 -1.347759 -1.270485  0.969397
# 2 -1.173123  1.943621 -0.413619 -0.747455
# 3  1.922942  1.480515  1.867559  0.906045
# <Axes: ylabel='Frequency'>

# %%
import pandas as pd
import numpy as np

np.random.seed(0)
df=pd.DataFrame(np.random.randn(4,4), columns=['zero', 'one', 'two', 'three'])
color_list=['blue', 'green', 'red', 'orange']
print(df)
df.plot(kind='box')
# Out:
#        zero       one       two     three
# 0  1.764052  0.400157  0.978738  2.240893
# 1  1.867558 -0.977278  0.950088 -0.151357
# 2 -0.103219  0.410599  0.144044  1.454274
# 3  0.761038  0.121675  0.443863  0.333674
# <Axes: >

# %% [markdown]
# ![Image](data:image/png;base64,...)

# %%
# !pip install matplotlib
import matplotlib.pyplot as plt
import numpy as np

t = np.arange(0., 5., 0.2)
print(t)

plt.plot(t, t, 'r.', t, t**2, 'b*', t, t**3, 'g+', t, t**4, 'y-')
plt.show()
# Out:
# [0.  0.2 0.4 0.6 0.8 1.  1.2 1.4 1.6 1.8 2.  2.2 2.4 2.6 2.8 3.  3.2 3.4
#  3.6 3.8 4.  4.2 4.4 4.6 4.8]

# %% [markdown]
# ![Image](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
slang_usage = ['Rarely', 'Sometimes', 'Never', 'Often']
# my_colors = ["#dde5b6", "#adc178", "#a98467", "#6c584c"]
# my_colors = ['silver', 'gold', 'whitesmoke', 'lightgray']
my_colors = plt.cm.Greens(np.linspace(0.2, 1, len(slang_usage)))
values = [438, 401, 195, 109]
plt.pie(values, labels=slang_usage, autopct='%.1f%%', colors=my_colors)
plt.title('Pie Chart')
plt.show()

# %% [markdown]
# ![Image](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import numpy as np

x=list(np.arange(5))
years=['2019', '2020', '2021', '2022', '2023']
values=[100, 400, 600, 800, 900]
my_colors=['r', 'b', 'g', 'y', 'violet']

plt.bar(x, values, color=my_colors, width=0.5)
plt.xticks(x, years)
plt.title('Cumulative purchase ')

plt.xlabel('Year')
plt.ylabel('Purchase')

for i, v in enumerate(x):
    plt.text(v, values[i], values[i], fontsize=10,
            color='blue',
            horizontalalignment='center',
            verticalalignment='bottom')

plt.show()

# %% [markdown]
# ![Image](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import numpy as np

y=list(np.arange(5))  # [0, 1, 2, 3, 4]
years=['2019', '2020', '2021', '2022', '2023']
values=[100, 400, 600, 800, 900]
my_colors=['r', 'b', 'g', 'y', 'violet']

bars=plt.barh(y, values, color=my_colors, height=0.7)
plt.yticks(y, years)

plt.title('Cumulative purchase')
plt.ylabel('Year')
plt.xlabel('Purchase')

for bar, value in zip(bars, values):
    plt.text(bar.get_width(), bar.get_y() + bar.get_height() / 2, str(value),
             ha='left', va='center')
plt.show()

# %% [markdown]
# ![Image](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(1, 20, 2)
y = np.random.randint(20, size=10)

plt.scatter(x, y, color='b')

plt.title('Scatter Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.xticks(x, x)
y_ticks = np.arange(0, max(y) + 1, 2)
plt.yticks(y_ticks)

plt.show()

# %% [markdown]
# ![Image](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(0)

n = 50
x = np.random.rand(n)
y = np.random.rand(n)
area = (30 * np.random.rand(n))**2
colors = np.random.rand(n)

plt.scatter(x, y, s=area, c=colors, cmap='plasma')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(0)

n = 50
x = np.random.rand(n)
y = np.random.rand(n)
area =  (30*y)**2
colors = np.random.rand(n)

plt.scatter(x, y, s=area, c=colors, cmap='plasma')
plt.show()

# %% [markdown]
# ![Image](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(-10, 10, 0.1)
y = np.sin(x)

plt.plot(x, y, label='sin(x)', color='blue',
     linestyle='-', linewidth=2)

plt.title('Line Graph')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 3, 5, 10])
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.axis([0, 5, 0, 20])  # X, Y축의 범위: [xmin, xmax, ymin, ymax]

plt.show()

# %% [markdown]
# ![Image](data:image/png;base64,...)

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'Value1': [10, 15, 25, 20, 30],
    'Value2': [5, 10, 15, 10, 20]
}

Date = ['2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01', '2023-05-01']
df = pd.DataFrame(data, index=Date)

plt.figure(figsize=(10, 6))
plt.fill_between(df.index, df['Value1'], label='Value1', color='skyblue', alpha=0.4)
plt.fill_between(df.index, df['Value2'], label='Value2', color='orange', alpha=0.4)

plt.title('Area Graph')
plt.xlabel('Date')
plt.ylabel('Values')

plt.legend()

plt.show()

# %%
## Practice

import pandas as pd
import numpy as np

def plot_line(df, xlabel, ylabel, title, legend_title):
    df.plot(kind='line', marker='o');     plt.title(title);     plt.xlabel(xlabel);     plt.ylabel(ylabel)
    plt.legend(title=legend_title);     plt.show()
    return

def plot_bar(df, xlabel, ylabel, title, legend_title):
    df.plot(kind='bar');     plt.title(title);     plt.xlabel(xlabel);     plt.ylabel(ylabel)
    plt.legend(title=legend_title);     plt.show()
    return

def plot_area(df, title):
    df.plot(kind='area', stacked=True);     plt.title(title);     plt.show()
    return

def plot_pie(df, title):
    colors = plt.cm.Paired(range(len(df.columns)));    sum_df = df.sum(axis=1)
    sum_df.plot(kind='pie', autopct='%1.1f%%', colors=colors);     plt.title(title);     plt.show()
    return 0

def draw_plots(df, xlabel, ylabel, title, legend_title):
    plot_line(df,  xlabel, ylabel, title, legend_title)
    plot_bar(df,  xlabel, ylabel, title, legend_title)
    plot_area(df, title)
    plot_pie(df, title)
    return

item_list = ['Americano', 'Latte', 'Tea', 'Juice', 'Cake']  # 품목명
customer_list = ['Irene', 'Edith', 'Gaby', 'Anna', 'Erica', 'Charles', 'Bailey'] # 고객 이름

customer_purchase={}
for item in item_list: # 각 품목의 구매액을 10,000~30,000 사이로 고객 수 만큼 생성
    customer_purchase[item] = np.random.randint(10, 30, len(customer_list))
cp_df = pd.DataFrame(customer_purchase, index=customer_list)  # data frame 생성
print(cp_df)
draw_plots(cp_df, 'Customers', 'Amount', 'Customer-Item types', 'Customers')

pc_df=cp_df.transpose()
print(pc_df)
draw_plots(pc_df, 'Item types', 'Amount', 'Item types-Customer', 'Item Types')
# Out:
#          Americano  Latte  Tea  Juice  Cake
# Irene           10     18   17     22    11
# Edith           21     12   19     13    22
# Gaby            18     29   19     19    12
# Anna            20     29   19     20    12
# Erica           21     24   13     23    11
# Charles         15     13   24     17    15
# Bailey          25     13   28     17    18
#            Irene  Edith  Gaby  Anna  Erica  Charles  Bailey
# Americano     10     21    18    20     21       15      25
# Latte         18     12    29    29     24       13      13
# Tea           17     19    19    19     13       24      28
# Juice         22     13    19    20     23       17      17
# Cake          11     22    12    12     11       15      18

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

item_list = ['Americano', 'Latte', 'Tea', 'Juice', 'Cake']
customer_list = ['Irene', 'Edith', 'Gaby', 'Anna', 'Erica', 'Charles', 'Bailey']
customer_purchase = {}
for item in item_list:
    customer_purchase[item] = np.random.randint(10, 50, len(customer_list))

cp_df = pd.DataFrame(customer_purchase, index=customer_list)
plt.figure(figsize=(10, 6))

scatter = plt.scatter(
    np.repeat(cp_df.index, len(cp_df.columns)),
    np.tile(cp_df.columns, len(cp_df.index)),
    c=cp_df.values.flatten(), cmap='viridis', s=cp_df.values.flatten() * 20
)
plt.colorbar(scatter, label='Purchase Amount')
plt.xlabel('Customer')
plt.ylabel('Product')
plt.title('Customer Purchase Amounts for Each Product')

plt.show()
